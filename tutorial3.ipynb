# %%
d = {'user': 'bozo', 'pswd': 1234}
d['user']
# Out:
# 'bozo'

# %%
d = {'user': 'bozo', 'pswd': 1234}
d['pswd']
# Out:
# 1234

# %%
d = {'user': 'bozo', 'pswd': 1234}
d['bozo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-b9abe9ba7e89> in <module>
#       1 d = {'user': 'bozo', 'pswd': 1234}
# ----> 2 d['bozo']
#
# KeyError: 'bozo'

# %%
d = {'user': 'bozo', 'pswd': 1234}
d['user'] = 'clown'
d
# Out:
# {'user': 'clown', 'pswd': 1234}

# %%
d = {'user': 'bozo', 'pswd': 1234}
d['user'] = 'clown'
d['id'] = 45
d
# Out:
# {'user': 'clown', 'pswd': 1234, 'id': 45}

# %%
d = {'user': 'bozo', 'p': 1234, 'i' :34}
del d['user']
d
# Out:
# {'p': 1234, 'i': 34}

# %%
d = {'user': 'bozo', 'p': 1234, 'i' :34}
d.clear()
d
# Out:
# {}

# %%
d = {'user': 'bozo', 'p': 1234, 'i' :34}
a=[1,2]
del a[1]
a
# Out:
# [1]

# %%
d = {'user': 'bozo', 'p': 1234, 'i' :34}
d.keys()
# Out:
# dict_keys(['user', 'p', 'i'])

# %%
d = {'user': 'bozo', 'p': 1234, 'i' :34}
d.values()
# Out:
# dict_values(['bozo', 1234, 34])

# %%
d = {'user': 'bozo', 'p': 1234, 'i' :34}
d.items()
# Out:
# dict_items([('user', 'bozo'), ('p', 1234), ('i', 34)])
